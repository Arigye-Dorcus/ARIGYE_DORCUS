# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# %%
df=pd.read_csv('customer_data_records.csv')

print(df)
# Out:
#      CustomerID  Annual Income (k$)  Spending Score (1-100)
# 0             1                 117                      20
# 1             2                 107                      59
# 2             3                  29                      36
# 3             4                 121                      19
# 4             5                  86                      90
# ..          ...                 ...                     ...
# 169         170                 111                      76
# 170         171                 138                      87
# 171         172                  84                      15
# 172         173                 107                      92
# 173         174                  17                      98
#
# [174 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['CustomerID', 'Annual Income (k$)', 'Spending Score (1-100)'], dtype='object')

# %%
#select features for clustering
x = df[['Annual Income (k$)','Spending Score (1-100)']]

# %%
#apply k-Means clustering
#use only two clusters
kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(x)
# Out:
# KMeans(n_clusters=2, random_state=0)

# %%
#add cluster label to dataset
df['Cluster'] = kmeans.labels_
print(df)
# Out:
#      CustomerID  Annual Income (k$)  Spending Score (1-100)  Cluster
# 0             1                 117                      20        1
# 1             2                 107                      59        1
# 2             3                  29                      36        0
# 3             4                 121                      19        1
# 4             5                  86                      90        0
# ..          ...                 ...                     ...      ...
# 169         170                 111                      76        1
# 170         171                 138                      87        1
# 171         172                  84                      15        0
# 172         173                 107                      92        1
# 173         174                  17                      98        0
#
# [174 rows x 4 columns]

# %%
#visualize the cluster
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Annual Income (k$)', y='Spending Score (1-100)', hue='Cluster')
plt.title('Customer Clusters based on Income & Spending')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score(1-100)')
plt.show()

# %%
df.columns
# Out:
# Index(['CustomerID', 'Annual Income (k$)', 'Spending Score (1-100)',
#        'Cluster'],
#       dtype='object')

# %%
z= df[['CustomerID','Annual Income (k$)']]
kmeans.fit(z)
df['cluster'] = kmeans.labels_

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df,y='Annual Income (k$)',x='CustomerID',hue='cluster')
plt.title('customer income')
plt.ylabel('Annual Income (k$)')
plt.xlabel('CustomerID')
plt.show()

# %%
#customers expenditure
r=df[['CustomerID','Spending Score (1-100)']]
kmeans.fit(r)
df['cluster'] =kmeans.labels_

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df,y='Spending Score (1-100)',x='CustomerID',hue='cluster')
plt.title('customer spending')
plt.ylabel('Spending Score (1-100)')
plt.xlabel('CustomerID')
plt.show()
