# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
import numpy as np

#load the file
df=pd.read_csv('climate_action_data.csv')

# %%
df.head(21)
# Out:
#    Sensor_ID        Date Soil_Moisture(%) Soil_pH Temperature(C) Humidity(%)  \
# 0   SEN-1000  2025-01-01            36.22    6.98           21.3        50.4
# 1   SEN-1001  2025-01-02            76.55    5.03           23.5        34.3
# 2   SEN-1002  2025-01-03            61.24    6.52           21.9        54.6
# 3   SEN-1003  2025-01-04            51.91    6.62           24.0        48.7
# 4   SEN-1004  2025-01-05            20.92    5.98           19.2        70.6
# 5   SEN-1005  2025-01-06            20.92    7.08           26.8        66.3
# 6   SEN-1006  2025-01-07            14.07    7.77           19.1        51.9
# 7   SEN-1007  2025-01-08            70.63    7.74           31.6        43.1
# 8   SEN-1008  2025-01-09            52.08    6.08           22.0        89.3
# 9   SEN-1009  2025-01-10            59.57     4.9           27.2        57.2
# 10  SEN-1010  2025-01-11            11.44    7.95           33.0        71.3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913 entries, 0 to 912
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Sensor_ID                      913 non-null    object
#  1   Date                           909 non-null    object
#  2   Soil_Moisture(%)               913 non-null    object
#  3   Soil_pH                        913 non-null    object
#  4   Temperature(C)                 913 non-null    object
#  5   Humidity(%)                    913 non-null    object
#  6   Crop_Type                      909 non-null    object
#  7   Fertilizer_Recommended(kg/ha)  913 non-null    object
#  8   Irrigation_Recommended(mm)     913 non-null    object
#  9   Drone_Image_ID                 913 non-null    object
# dtypes: object(10)
# memory usage: 71.5+ KB

# %%
df.describe()
# Out:
#        Sensor_ID        Date Soil_Moisture(%) Soil_pH Temperature(C)  \
# count        913         909              913     913            913
# unique       800         798              750     313            170
# top     SEN-1430  2026-09-10            error    7.54           19.1
# freq           2           2                5      11             13
#
#        Humidity(%) Crop_Type Fertilizer_Recommended(kg/ha)  \
# count          913       909                           913
# unique         448         5                           595
# top           56.0     Wheat                          66.9
# freq             8       203                             8
#
#        Irrigation_Recommended(mm) Drone_Image_ID
# count                         913            913
# unique                        243            800
# top                           8.0       IMG-2430
# freq                           11              2

# %%
print(df.dtypes)
# Out:
# Sensor_ID                        object
# Date                             object
# Soil_Moisture(%)                 object
# Soil_pH                          object
# Temperature(C)                   object
# Humidity(%)                      object
# Crop_Type                        object
# Fertilizer_Recommended(kg/ha)    object
# Irrigation_Recommended(mm)       object
# Drone_Image_ID                   object
# dtype: object

# %%
print(f'rows and columns \n{df.shape}')
# Out:
# rows and columns
# (913, 10)

# %%
columns1=list(df.columns)
print(columns1)
# Out:
# ['Sensor_ID', 'Date', 'Soil_Moisture(%)', 'Soil_pH', 'Temperature(C)', 'Humidity(%)', 'Crop_Type', 'Fertilizer_Recommended(kg/ha)', 'Irrigation_Recommended(mm)', 'Drone_Image_ID']

# %%
df.isnull().sum()
# Out:
# Sensor_ID                        0
# Date                             4
# Soil_Moisture(%)                 0
# Soil_pH                          0
# Temperature(C)                   0
# Humidity(%)                      0
# Crop_Type                        4
# Fertilizer_Recommended(kg/ha)    0
# Irrigation_Recommended(mm)       0
# Drone_Image_ID                   0
# dtype: int64

# %%
df['Crop_Type'] = df['Crop_Type'].fillna(df['Crop_Type'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Sensor_ID                        0
# Date                             4
# Soil_Moisture(%)                 0
# Soil_pH                          0
# Temperature(C)                   0
# Humidity(%)                      0
# Crop_Type                        0
# Fertilizer_Recommended(kg/ha)    0
# Irrigation_Recommended(mm)       0
# Drone_Image_ID                   0
# dtype: int64

# %%
df['Date']=pd.to_datetime(df['Date'])
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913 entries, 0 to 912
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Sensor_ID                      913 non-null    object
#  1   Date                           909 non-null    datetime64[ns]
#  2   Soil_Moisture(%)               913 non-null    object
#  3   Soil_pH                        913 non-null    object
#  4   Temperature(C)                 913 non-null    object
#  5   Humidity(%)                    913 non-null    object
#  6   Crop_Type                      913 non-null    object
#  7   Fertilizer_Recommended(kg/ha)  913 non-null    object
#  8   Irrigation_Recommended(mm)     913 non-null    object
#  9   Drone_Image_ID                 913 non-null    object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 71.5+ KB
# None

# %%
#change to numeric values and  Handle missing values

numeric_columns =['Soil_Moisture(%)','Soil_pH','Temperature(C)','Humidity(%)','Irrigation_Recommended(mm)','Fertilizer_Recommended(kg/ha)']
for col in numeric_columns:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce') 
        df[col] = df[col].fillna(df[col].median())
        
print("Missing values after handling:")
print(df.isnull().sum())
# Out:
# Missing values after handling:
# Sensor_ID                        0
# Date                             4
# Soil_Moisture(%)                 0
# Soil_pH                          0
# Temperature(C)                   0
# Humidity(%)                      0
# Crop_Type                        0
# Fertilizer_Recommended(kg/ha)    0
# Irrigation_Recommended(mm)       0
# Drone_Image_ID                   0
# dtype: int64

# %%
print(df.to_string())
# Out:
#     Sensor_ID       Date  Soil_Moisture(%)  Soil_pH  Temperature(C)  Humidity(%) Crop_Type  Fertilizer_Recommended(kg/ha)  Irrigation_Recommended(mm) Drone_Image_ID
# 0    SEN-1000 2025-01-01            36.220    6.980            21.3         50.4  Tomatoes                           67.6                        26.6       IMG-2000
# 1    SEN-1001 2025-01-02            76.550    5.030            23.5         34.3     Wheat                          130.4                         8.3       IMG-2001
# 2    SEN-1002 2025-01-03            61.240    6.520            21.9         54.6  Tomatoes                           36.0                        29.4       IMG-2002
# 3    SEN-1003 2025-01-04            51.910    6.620            24.0         48.7     Maize                           85.8                        19.6       IMG-2003
# ...

# %%
print(df.isnull().sum())
# Out:
# Sensor_ID                        0
# Date                             4
# Soil_Moisture(%)                 0
# Soil_pH                          0
# Temperature(C)                   0
# Humidity(%)                      0
# Crop_Type                        0
# Fertilizer_Recommended(kg/ha)    0
# Irrigation_Recommended(mm)       0
# Drone_Image_ID                   0
# dtype: int64

# %%
#null dates 
df['Date']=pd.to_datetime(df['Date'],errors='coerce')
print(df.isnull().sum())
# Out:
# Sensor_ID                        0
# Date                             4
# Soil_Moisture(%)                 0
# Soil_pH                          0
# Temperature(C)                   0
# Humidity(%)                      0
# Crop_Type                        0
# Fertilizer_Recommended(kg/ha)    0
# Irrigation_Recommended(mm)       0
# Drone_Image_ID                   0
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Sensor_ID                        0
# Date                             4
# Soil_Moisture(%)                 0
# Soil_pH                          0
# Temperature(C)                   0
# Humidity(%)                      0
# Crop_Type                        0
# Fertilizer_Recommended(kg/ha)    0
# Irrigation_Recommended(mm)       0
# Drone_Image_ID                   0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 908     True
# 909     True
# 910     True
# 911     True
# 912     True
# Length: 913, dtype: bool

# %%
df=df.drop_duplicates()
print(f'Number of rows after dropping rows: {df.shape[0]}')
# Out:
# Number of rows after dropping rows: 802

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 797    False
# 798    False
# 799    False
# 801    False
# 863    False
# Length: 802, dtype: bool

# %%
# print(df.describe())
print(df.isnull().sum())
print(df.duplicated().sum())
# Out:
# Sensor_ID                        0
# Date                             4
# Soil_Moisture(%)                 0
# Soil_pH                          0
# Temperature(C)                   0
# Humidity(%)                      0
# Crop_Type                        0
# Fertilizer_Recommended(kg/ha)    0
# Irrigation_Recommended(mm)       0
# Drone_Image_ID                   0
# dtype: int64
# 0

# %%
#correlation
corr_matrix=df[['Soil_Moisture(%)','Soil_pH','Temperature(C)','Humidity(%)','Fertilizer_Recommended(kg/ha)','Irrigation_Recommended(mm)']].corr()
plt.figure(figsize=(11,7))
sns.heatmap(corr_matrix,cmap='RdBu',annot=True, fmt='.2f', linewidths=0.5, center=0)
plt.title("A correlation heatmap")
plt.show()

# %%
df.groupby('Crop_Type')['Fertilizer_Recommended(kg/ha)'].mean().sort_values(ascending=False)
# Out:
# Crop_Type
# Tomatoes    88.898214
# Maize       88.485806
# Lettuce     87.997351
# Wheat       87.796023
# Beans       83.905263
# Name: Fertilizer_Recommended(kg/ha), dtype: float64

# %%
#histograms for the numeric values 
plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
plt.title("Soil_Moisture(%) Distribution")
sns.histplot(df['Soil_Moisture(%)'],bins=30,kde=True)

plt.subplot(1,2,2)
plt.title("Soil_pH Distribution")
sns.histplot(df['Soil_pH'],bins=30,kde=True)
plt.show()

# %%
#histograms for the numeric values 
plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
plt.title("Temperature(C) Distribution")
sns.histplot(df['Temperature(C)'],bins=30,kde=True)

plt.subplot(1,2,2)
plt.title("Humidity(%) Distribution")
sns.histplot(df['Humidity(%)'],bins=30,kde=True)
plt.show()

# %%
#histograms for the numeric values 
plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
plt.title("Fertilizer_Recommended(kg/ha) Distribution")
sns.histplot(df['Fertilizer_Recommended(kg/ha)'],bins=30,kde=True)

plt.subplot(1,2,2)
plt.title("Irrigation_Recommended(mm) Distribution")
sns.histplot(df['Irrigation_Recommended(mm)'],bins=30,kde=True)
plt.show()

# %%
# Relationships Between Soil & Environmental Variables
# Key Correlations from the Heatmap:

# Soil pH shows the strongest positive correlation with Fertilizer_Recommended (r = 0.08)

# All other correlations are very weak (|r| < 0.05), suggesting:

# Soil moisture, temperature, and humidity have minimal linear relationships with fertilizer/irrigation recommendations in this dataset

# %%
# Variables Influencing Fertilizer Recommendations
# Top Influencer:
# Soil_pH (r = 0.08 with fertilizer)
# Despite the weak correlation, it's the strongest influencer in this dataset

# %%
#determining the crop type with the highest average soil moisture,

max_soil_moisture=df.groupby('Crop_Type')['Soil_Moisture(%)'].mean()
crop=max_soil_moisture.idxmax()
max_value=max_soil_moisture.max()
print(f'crop  with max average value: \n{crop} ={max_value}')
# Out:
# crop  with max average value:
# Wheat =47.356448863636366

# %%
# appropriate irrigation adjustments for crops experiencing average temperatures above 30°C.
average_temp=df.groupby('Crop_Type')['Temperature(C)'].mean()
crops=average_temp
print(crops)
# Out:
# Crop_Type
# Beans       26.855921
# Lettuce     26.162252
# Maize       27.010323
# Tomatoes    26.170833
# Wheat       26.171591
# Name: Temperature(C), dtype: float64

# %%
#suggest appropriate irrigation adjustments for crops experiencing average temperatures above 30°C.
#For crops experiencing temperatures above 30°C, increase irrigation by 5% per 1°C above 30°C, but reduce adjustments by 2% if humidity >60% or 10% if soil moisture >60% to optimize water use. Always verify with soil sensors to prevent over/under-watering

# %%
plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
plt.title("Average temperature vs crops")
sns.barplot(y=average_temp,x=crops_above_30) # type: ignore
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 4
#       2 plt.subplot(1,2,1)
#       3 plt.title("Average temperature vs crops")
# ----> 4 sns.barplot(y=average_temp,x=crops_above_30)
#
# NameError: name 'crops_above_30' is not defined

# %%
# export your clean dataset as cleaned_precision_agriculture_data.csv

df.to_csv('cleaned_precision_agriculture_data.csv')

# %%
# #insits from the analysis
# Soil pH is the Primary Driver for fertilizer recommendations, showing the strongest correlation (r=0.08), though relationships are generally weak in the dataset.

# No Significant Linear Patterns exist between temperature/humidity and irrigation recommendations, suggesting adjustments should rely on agronomic best practices (e.g., +5% water per 1°C above 30°C) rather than dataset trends.

# Context-Specific Adjustments are critical—reduce irrigation increases by 2% in high humidity (>60%) or 10% in high soil moisture (>60%) to avoid overwatering while mitigating heat stress.

# %%
# #Recomendation for future collection of data
# Record subsoil moisture (at different depths) and nutrient levels (N, P, K) to better understand soil-fertility dynamics.
# Collect hourly/daily sensor readings (not just averages) to capture short-term stress events
# Validate crop growth stages (e.g., flowering, fruiting) to tailor recommendations.
